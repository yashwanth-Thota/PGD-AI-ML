# %%
# !pip install streamlit wordcloud
# Out:
# Requirement already satisfied: streamlit in /Users/yathota/anaconda3/lib/python3.10/site-packages (1.23.1)
# Collecting wordcloud
#   Downloading wordcloud-1.9.2.tar.gz (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 4.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging<24,>=14.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (22.0)
# Requirement already satisfied: requests<3,>=2.4 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: tzlocal<5,>=1.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (4.3)
# Requirement already satisfied: validators<1,>=0.2 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: pydeck<1,>=0.1.dev5 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (4.4.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: pyarrow>=4.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (6.1)
# Requirement already satisfied: altair<6,>=4.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (3.1.31)
# Requirement already satisfied: numpy<2,>=1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (1.23.5)
# Requirement already satisfied: rich<14,>=10.11.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (13.4.1)
# Requirement already satisfied: toml<2 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: python-dateutil<3,>=2 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: pillow<10,>=6.2.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (8.0.1)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (4.23.2)
# Requirement already satisfied: pandas<3,>=0.25 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pympler<2,>=0.9 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: matplotlib in /Users/yathota/anaconda3/lib/python3.10/site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: jinja2 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /Users/yathota/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from pandas<3,>=0.25->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from python-dateutil<3,>=2->streamlit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.4->streamlit) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.4->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.4->streamlit) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from rich<14,>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from rich<14,>=10.11.0->streamlit) (2.15.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/yathota/anaconda3/lib/python3.10/site-packages (from tzlocal<5,>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/yathota/anaconda3/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.11.0->streamlit) (0.1.2)
# Requirement already satisfied: tzdata in /Users/yathota/anaconda3/lib/python3.10/site-packages (from pytz-deprecation-shim->tzlocal<5,>=1.1->streamlit) (2023.3)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py) ... done
#   Created wheel for wordcloud: filename=wordcloud-1.9.2-cp310-cp310-macosx_11_0_arm64.whl size=152696 sha256=174d596bc24b2c810efa45e816ff32f717dd2176f49e0ca32c0976ff81718ddf
#   Stored in directory: /Users/yathota/Library/Caches/pip/wheels/90/19/0b/f5cad0167bc462f4f87cbd86590c27afbe599d5a37011bcf78
# Successfully built wordcloud
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

DATA_URL = (
    "vgssales.csv"
)

st.title("Exploratory Data Analysis: Video Games Sales")

st.sidebar.title("EDA: Video Games Sales")

st.markdown("This application is a Streamlit dashboard used "
            "to analyze Video Games Sales")
st.sidebar.markdown("This application is a Streamlit dashboard used "
            "to analyze Video Games Sales")


@st.cache(persist=True)
def load_data():
    df = pd.read_csv(DATA_URL)
    
    return df

df = load_data()

st.table(df.head())


a = st.sidebar.selectbox('Tasks', ['Task 1', 'Task 2', 'Task 3', 'Task 4', 'Task 5', 'Task 6', 'Task 7'], key='2')
if a == 'Task 1':
    alltimesales =round(df.groupby(["Genre"]).mean(),2)
    alltimesales.reset_index(inplace=True)

    fig = px.bar(alltimesales.sort_values('Global_Sales'), 
             x='Global_Sales', y='Genre', title='Average Global Sales(million dollars) across years for different Game Genres'
             , text='Global_Sales', orientation='h')

    st.plotly_chart(fig)
    st.subheader('Observation:\nPlatform Genre has the Highest Sales')

if a == 'Task 2':
    platform=pd.DataFrame(df['Platform'].value_counts())
    platform.reset_index(inplace=True)
    platform.rename(columns={'index':'Platform','Platform':'Number of Games'},inplace=True)

    fig = px.bar(platform.sort_values('Number of Games'), 
             x='Number of Games', y='Platform', title='Number of games across different platforms', 
             text='Number of Games', orientation='h')
    st.plotly_chart(fig)
    st.header('Observations')
    st.subheader('DS platform has the number of games across all the platforms')
    st.subheader('PS3 platform is very close to the highest platform')

if a == 'Task 3':
    yearlyreleases=pd.DataFrame(df['Year'].value_counts())
    yearlyreleases.reset_index(inplace=True)
    yearlyreleases.rename(columns={'index':'Year','Year':'Number of Releases'},inplace=True)
    fig = px.bar(yearlyreleases.sort_values('Year',ascending=True), 
             x='Number of Releases', y='Year', title='Number of games released in each year', 
             text='Number of Releases', orientation='h')
    st.plotly_chart(fig)
    st.header('Observations')
    st.subheader('Most of the Games were released in the 20th Century')
    st.subheader('Number of releases suddenly increased after 2004, and started to decrease after 2011')
    st.subheader('Very few games were released in late 19th Century')

if a == 'Task 4':
    salespergenre=df.groupby('Genre').sum()
    salespergenre['percentagesales']=round(salespergenre['Global_Sales']/(salespergenre['Global_Sales'].sum()),4)*100
    salespergenre.reset_index(inplace=True)
    fig = px.pie(salespergenre, names='Genre', values='percentagesales',template='presentation', title = 'Percentage Share of Each Genre in Global Sales')
    st.plotly_chart(fig)
    st.header('Observations')
    st.subheader('**Action** Genre has contributed most to the Global Sales followed by **Sports** and **Shooter** Genre games')
    st.subheader('**Strategy** and **Puzzle** genre games brought in the lowest sales because most of the people find such games boring. So, to increase Global Sales, a Gaming company should focus on creating more Action, Sports and Shooter games as they bring in the most number of Sales')

if a == 'Task 5':
    fig = px.scatter(df, x="Year", y="Global_Sales", color="Genre", hover_data=['Publisher'])
    st.plotly_chart(fig)
    st.subheader('Observations')
    st.subheader('In the year 2006, **Nintendo** recorded the Highest Global Sales in Sports Genre')
    st.subheader('**Strategy** Genre Games has been consistenly performing very bad')
    st.subheader('**Nintendo** is consistenly bringing in highest Global Sales in the year 2005, 2006, 2008')



platformsales=df[['Platform','Year','Global_Sales']]
platformsales['Netplatformsales']=platformsales.groupby(['Platform','Year'])['Global_Sales'].transform('sum')
desiredplatforms=['PS2','PS','Wii','PSP','PS','PC','XB','GBA']

#desiredplatforms=['PS3','X360']

platformsales=platformsales[(platformsales['Year']>=2005) & (platformsales['Year']<=2015) & (platformsales['Platform'].isin(desiredplatforms))]
platformsales=platformsales.sort_values('Year',ascending=True)
platformsales.drop_duplicates()
platformsales.drop('Global_Sales', axis=1, inplace=True)

if a == 'Task 6':


    fig=px.bar(platformsales,x='Platform', y='Netplatformsales', animation_frame="Year",range_y=[0,220], 
           animation_group='Netplatformsales', hover_name='Platform',color_discrete_sequence=px.colors.qualitative.D3,
          title='Change in Net Sales(million $) across different platforms from 2005 to 2015')
    st.plotly_chart(fig)

if a == 'Task 7':
    publishersales=df[['Publisher','Year','Global_Sales']]
    publishersales['Netpublishersales']=publishersales.groupby(['Publisher','Year'])['Global_Sales'].transform('sum')
    desiredpublisher=['Electronic Arts','Activison','Namco Bandal Games','Ubisoft','Konami Digital Entertainment',
                  'THQ','Nintendo','Sega','Sony Computer Entertainment','Take-Two Interactive']

    publishersales=publishersales[(platformsales['Year']>=2005) & (platformsales['Year']<=2015) & (publishersales['Publisher'].isin(desiredpublisher))]
    publishersales=publishersales.sort_values('Year',ascending=True)
    publishersales.drop_duplicates()
    publishersales.drop('Global_Sales', axis=1, inplace=True)

    fig=px.bar(publishersales,x='Publisher', y='Netpublishersales', animation_frame="Year",range_y=[0,210], 
           animation_group="Netpublishersales", hover_name="Publisher",color_discrete_sequence=px.colors.qualitative.D3,width=1000, height=500
          ,title='Change in Net Sales(million $) of different Publishers from 2005 to 2015')
    st.plotly_chart(fig)
# Out:
# 2023-06-04 20:39:45.112
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/yathota/anaconda3/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:360, in _CodeHasher.to_bytes(self, obj, context)
#     358 try:
#     359     # Hash the input
# --> 360     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     362     # Hmmm... It's possible that the size calculation is wrong. When we
#     363     # call to_bytes inside _to_bytes things get double-counted.
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:626, in _CodeHasher._to_bytes(self, obj, context)
#     625 assert code is not None
# --> 626 if self._file_should_be_hashed(code.co_filename):
#     627     context = _get_context(obj)
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:402, in _CodeHasher._file_should_be_hashed(self, filename)
#     400     return False
#     401 return file_util.file_is_in_folder_glob(
# --> 402     filepath, self._get_main_script_directory()
#     403 ) or file_util.file_in_pythonpath(filepath)
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:714, in _CodeHasher._get_main_script_directory()
#     712 # This works because we set __main__.__file__ to the
#     713 # script path in ScriptRunner.
# --> 714 abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     715 return str(abs_main_path.parent)
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# Cell In[5], line 31
#      27     df = pd.read_csv(DATA_URL)
#      29     return df
# ---> 31 df = load_data()
#      33 st.table(df.head())
#      36 a = st.sidebar.selectbox('Tasks', ['Task 1', 'Task 2', 'Task 3', 'Task 4', 'Task 5', 'Task 6', 'Task 7'], key='2')
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/caching.py:715, in cache.<locals>.wrapped_func(*args, **kwargs)
#     713 if show_spinner:
#     714     with spinner(message):
# --> 715         return get_or_create_cached_value()
#     716 else:
#     717     return get_or_create_cached_value()
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/caching.py:637, in cache.<locals>.wrapped_func.<locals>.get_or_create_cached_value()
#     630 nonlocal cache_key
#     631 if cache_key is None:
#     632     # Delay generating the cache key until the first call.
#     633     # This way we can see values of globals, including functions
#     634     # defined after this one.
#     635     # If we generated the key earlier we would only hash those
#     636     # globals by name, and miss changes in their code or value.
# --> 637     cache_key = _hash_func(non_optional_func, hash_funcs)
#     639 # First, get the cache that's attached to this function.
#     640 # This cache's key is generated (above) from the function's code.
#     641 mem_cache = _mem_caches.get_cache(cache_key, max_entries, ttl)
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/caching.py:767, in _hash_func(func, hash_funcs)
#     756 update_hash(
#     757     (func.__module__, func.__qualname__),
#     758     hasher=func_hasher,
#    (...)
#     761     hash_source=func,
#     762 )
#     764 # Include the function's body in the hash. We *do* pass hash_funcs here,
#     765 # because this step will be hashing any objects referenced in the function
#     766 # body.
# --> 767 update_hash(
#     768     func,
#     769     hasher=func_hasher,
#     770     hash_funcs=hash_funcs,
#     771     hash_reason=HashReason.CACHING_FUNC_BODY,
#     772     hash_source=func,
#     773 )
#     774 cache_key = func_hasher.hexdigest()
#     775 _LOGGER.debug(
#     776     "mem_cache key for %s.%s: %s", func.__module__, func.__qualname__, cache_key
#     777 )
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:108, in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     105 hash_stacks.current.hash_source = hash_source
#     107 ch = _CodeHasher(hash_funcs)
# --> 108 ch.update(hasher, val, context)
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:385, in _CodeHasher.update(self, hasher, obj, context)
#     383 def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     384     """Update the provided hasher with the hash of an object."""
# --> 385     b = self.to_bytes(obj, context)
#     386     hasher.update(b)
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:374, in _CodeHasher.to_bytes(self, obj, context)
#     371     raise
#     373 except Exception as ex:
# --> 374     raise InternalHashError(ex, obj)
#     376 finally:
#     377     # In case an UnhashableTypeError (or other) error is thrown, clean up the
#     378     # stack so we don't get false positives in future hashing calls
#     379     hash_stacks.current.pop()
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:360, in _CodeHasher.to_bytes(self, obj, context)
#     356 hash_stacks.current.push(obj)
#     358 try:
#     359     # Hash the input
# --> 360     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     362     # Hmmm... It's possible that the size calculation is wrong. When we
#     363     # call to_bytes inside _to_bytes things get double-counted.
#     364     self.size += sys.getsizeof(b)
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:626, in _CodeHasher._to_bytes(self, obj, context)
#     624 code = getattr(obj, "__code__", None)
#     625 assert code is not None
# --> 626 if self._file_should_be_hashed(code.co_filename):
#     627     context = _get_context(obj)
#     628     defaults = getattr(obj, "__defaults__", None)
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:402, in _CodeHasher._file_should_be_hashed(self, filename)
#     399 if file_is_blacklisted:
#     400     return False
#     401 return file_util.file_is_in_folder_glob(
# --> 402     filepath, self._get_main_script_directory()
#     403 ) or file_util.file_in_pythonpath(filepath)
#
# File ~/anaconda3/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py:714, in _CodeHasher._get_main_script_directory()
#     710 import __main__
#     712 # This works because we set __main__.__file__ to the
#     713 # script path in ScriptRunner.
# --> 714 abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     715 return str(abs_main_path.parent)
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `load_data()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function load_data at 0x174b915a0>
# ```
#
# Please see the `hash_funcs` [documentation](https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.
